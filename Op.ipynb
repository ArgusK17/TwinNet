# %%
# for loop in range(1,2):
if True:
    Rate=0
    Number=50000
    IterNum=500
    index=0
#     !python dataPrepare.py --Rate=$Rate --index=$index --Num=$Number
#     python dataPrepare.py --Rate=0 --index=0 --Num=50000
    # !python main.py --Rate=$Rate --Iter=$IterNum --index=$index --Num=$Number --lr=1e-4 #Adam
#     python main.py --Rate=0 --Iter=400 --index=0 --Num=50000 --lr=1e-4
# Out:
# Files already downloaded and verified
# ==> Building model..
#
# Epoch: 0, Time: 0 s
# Batch: 500, tr_acc: 1.748, acc: 45.270%
# Epoch: 1, Time: 129 s
# Batch: 1000, tr_acc: 1.383, acc: 56.030%
# Epoch: 2, Time: 256 s
# Batch: 1500, tr_acc: 1.148, acc: 62.190%
# Epoch: 3, Time: 384 s
# Batch: 2000, tr_acc: 0.969, acc: 65.130%
# Epoch: 4, Time: 510 s
# Batch: 2500, tr_acc: 0.848, acc: 68.960%
# Epoch: 5, Time: 635 s
# Batch: 3000, tr_acc: 0.760, acc: 72.210%
# Epoch: 6, Time: 762 s
# Batch: 3500, tr_acc: 0.671, acc: 73.620%
# Epoch: 7, Time: 887 s
# Batch: 4000, tr_acc: 0.620, acc: 74.050%
# Epoch: 8, Time: 1014 s
# Batch: 4500, tr_acc: 0.553, acc: 75.430%
# Epoch: 9, Time: 1142 s
# Batch: 5000, tr_acc: 0.506, acc: 76.660%
# Epoch: 10, Time: 1269 s
# Batch: 5500, tr_acc: 0.456, acc: 77.580%
# Epoch: 11, Time: 1396 s
# Batch: 6000, tr_acc: 0.404, acc: 77.550%
# Epoch: 12, Time: 1521 s
# Batch: 6500, tr_acc: 0.362, acc: 78.320%
# Epoch: 13, Time: 1648 s
# ...

# %%
Rate=0.2
index=0

# !python dataPrepare.py --Rate=$Rate --index=$index
# Out:
# ==> Preparing data..
# ...
# 100.0%
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# 0 4
# 5000 6
# 10000 1
# 15000 0
# 20000 8
# 25000 6
# 30000 0
# 35000 5
# 40000 5
# 45000 7
# Error count:  10057
# Done.
